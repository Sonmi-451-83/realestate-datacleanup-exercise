# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds["latitude"] = ds["latitude"].str.replace(",",".").astype(float)
ds["longitude"] = ds["longitude"].str.replace(",",".").astype(float)
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
max_precio = ds["price"][ds["price"].idxmax()]
max_dir = ds["address"][ds["price"].idxmax()]

print(f"La casa con dirección en {max_dir} es la más cara y su precio es de {max_precio} euros")
# Out:
# La casa con dirección en El Escorial es la más cara y su precio es de 8500000 euros

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
min_precio = ds["price"][ds["price"].idxmin()]
min_dir = ds["address"][ds["price"].idxmin()]

print(f"La casa con dirección en {min_dir} es la más barata y su precio es de {min_precio} euros")
# Out:
# La casa con dirección en Parla es la más barata y su precio es de 0 euros

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
min_surface = ds["surface"][ds["surface"].idxmin()]
min_dir = ds["address"][ds["surface"].idxmin()]

print(f"La casa más pequeña está ubicada en {min_dir} y su superficie es de {min_surface} metros")

max_surface = ds["surface"][ds["surface"].idxmax()]
max_dir = ds["address"][ds["surface"].idxmax()]

print(f"La casa más grande está ubicada en {max_dir} y su superficie es de {max_surface} metros")
# Out:
# La casa más pequeña está ubicada en Calle Amparo,  Madrid Capital y su superficie es de 15.0 metros
# La casa más grande está ubicada en Sevilla la Nueva y su superficie es de 249000.0 metros

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
pop_string = ""

for x in ds["level5"].unique():
    pop_string = pop_string + x + ", "

print(pop_string)
# Out:
# Arganda del Rey, Fuenlabrada, Boadilla del Monte, Las Rozas de Madrid,  Madrid Capital, Villaviciosa de Odón, Pinto, Valdemoro, Navalcarnero, Pozuelo de Alarcón, Torrejón de Ardoz, Navalagamella, San Sebastián de los Reyes, Rivas-vaciamadrid, Alpedrete, Móstoles, San Fernando de Henares, Coslada, Becerril de la Sierra, Alcalá de Henares, Chinchón, Parla, Alcorcón, El Escorial, Leganés, Pedrezuela, Majadahonda, Villanueva de la Cañada, Villanueva del Pardillo, Torrelodones, Moralzarzal, Mejorada del Campo, Aranjuez, Corpa, Getafe, Velilla de San Antonio, Sevilla la Nueva, San Martín de la Vega, Villalbilla, Collado Villalba, Alcobendas, El Molar (Madrid), Moraleja de Enmedio, Algete, Campo Real, Torrejón de la Calzada, Colmenar Viejo, Valdemorillo, Fuente El Saz de Jarama, Tres Cantos, Arroyomolinos (Madrid), Griñón, Paracuellos de Jarama, Guadarrama, Titulcia, Galapagar, Collado Mediano, Los Molinos, San Lorenzo de El Escorial, Loeches, San Martín de Valdeiglesias, Navas del Rey, Bus
# ...

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
for col in ds:
    if ds[col].count() != ds[col].size:
        print(f"True: {col}")
    else:
        print(f"False: {col}")



for index, file in ds.iterrows():
    if file.count() != file.size:
        print(f"True: {index}")
    else:
        print(f"False: {index}")
# Out:
# False: Unnamed: 0
# False: id_realEstates
# False: isNew
# True: realEstate_name
# True: phone_realEstate
# False: url_inmueble
# True: rooms
# True: bathrooms
# True: surface
# False: price
# False: date
# True: description
# False: address
# False: country
# False: level1
# False: level2
# False: level3
# True: level4
# False: level5
# True: level6
# True: level7
# True: level8
# False: upperLevel
# False: countryId
# False: level1Id
# False: level2Id
# False: level3Id
# False: level4Id
# False: level5Id
# False: level6Id
# False: level7Id
# False: level8Id
# False: accuracy
# False: latitude
# False: longitude
# True: zipCode
# True: customZone
# True: 0
# True: 1
# True: 2
# True: 3
# True: 4
# True: 5
# True: 6
# True: 7
# True: 8
# True: 9
# True: 10
# True: 11
# True: 12
# True: 13
# True: 14
# True: 15
# True: 16
# True: 17
# True: 18
# True: 19
# True: 20
# True: 21
# True: 22
# True: 23
# True: 24
# True: 25
# True: 26
# True: 27
# True: 28
# True: 29
# True: 30
# True: 31
# ...

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
print(ds.size)

ds2 = ds.dropna(how='all')

print(ds2.size)

ds2 = ds.dropna()

print(ds2.size)

ds2 = ds.dropna(axis=1)

print(ds2.size)

ds2 = ds.dropna(axis=0)

print(ds2.size)
# Out:
# 567395
# 567395
# 0
# 383375
# 0

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
print(ds["price"][ds["level5"] == "Arroyomolinos (Madrid)"].mean())
# Out:
# 294541.59854014596

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
data = ds["price"][ds["level5"] == "Arroyomolinos (Madrid)"]

plt.figure(figsize = (10, 5))

plt.hist(data, bins = 30, alpha = 0.7)

plt.title("Histograma")
plt.show()

print(data.size)

'''
La conclusión es que la mayor parte de las viviendas tiene un precio entre 150 mil y 400 mil, encontrándose que el precio más común es en torno a 280 mil,
seguido muy de cerca por viviendas de un valor de unos 350 mil
'''
# Out:
# 137
# '\nLa conclusión es que la mayor parte de las viviendas tiene un precio entre 150 mil y 400 mil, encontrándose que el precio más común es en torno a 280 mil,\nseguido muy de cerca por viviendas de un valor de unos 350 mil\n'

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
if ds["price"][ds["level5"] == "Valdemorillo"].mean(numeric_only=True) > ds["price"][ds["level5"] == "Galapagar"].mean(numeric_only=True):
    print("Valdemorillo es más caro que Galapagar")
elif ds["price"][ds["level5"] == "Valdemorillo"].mean(numeric_only=True) == ds["price"][ds["level5"] == "Galapagar"].mean(numeric_only=True):
    print ("Galapagar y Valdemorillo tienen el mismo precio medio")
else:
    print("Galapagar es más caro que Valdemorillo")
# Out:
# Valdemorillo es más caro que Galapagar

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
ds['pps'] = ds["price"]/ds["surface"]

if ds["pps"][ds["level5"] == "Valdemorillo"].mean(numeric_only=True) > ds["pps"][ds["level5"] == "Galapagar"].mean(numeric_only=True):
    print("Valdemorillo es más caro que Galapagar")
elif ds["pps"][ds["level5"] == "Valdemorillo"].mean(numeric_only=True) == ds["pps"][ds["level5"] == "Galapagar"].mean(numeric_only=True):
    print ("Galapagar y Valdemorillo tienen el mismo precio medio")
else:
    print("Galapagar es más caro que Valdemorillo")
# Out:
# Galapagar es más caro que Valdemorillo

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
Xv = np.arange(0,ds["pps"][ds["level5"] == "Valdemorillo"].size,1)
Xg = np.arange(0,ds["pps"][ds["level5"] == "Galapagar"].size,1)

Valdemorillo = ds["pps"][ds["level5"] == "Valdemorillo"]
Galapagar = ds["pps"][ds["level5"] == "Galapagar"]

plt.figure(figsize = (10, 5))

plt.scatter(Xv, Valdemorillo, label = "Valdemorillo")
plt.scatter(Xg, Galapagar, label = "Galapagar")

plt.title("Precio por metro cuadrado")
plt.legend()
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
print(ds["id_realEstates"].nunique())
# Out:
# 14217

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
counts = ds["level5"].value_counts().reset_index().rename(columns={"index": "value", 0: "count"})

print(counts["level5"][0])
print(counts["count"][0])
# Out:
#  Madrid Capital
# 6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
ds3 = ds[ds["level5"].isin(["Fuenlabrada","Leganés","Getafe","Alcorcón"])]
print(ds3)
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
labels = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
values = [ds3["price"][ds3["level5"] == "Fuenlabrada"].median(numeric_only=True), ds3["price"][ds3["level5"] == "Leganés"].median(numeric_only=True), ds3["price"][ds3["level5"] == "Getafe"].median(numeric_only=True), ds3["price"][ds3["level5"] == "Alcorcón"].median(numeric_only=True)]

plt.figure(figsize = (10, 5))

plt.bar(labels, values)

plt.title("Gráfico de barras")
plt.show()

'''
El municipio con mayor precio por metro cuadrado es Alcorcón, siendo Fuenlabrada el más barato
'''
# Out:
# '\nEl municipio con mayor precio por metro cuadrado es Alcorcón, siendo Fuenlabrada el más barato\n'

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
precio_med = ds3["price"].mean()
print(f"Precio medio: {precio_med}")
precio_var = ds3["price"].var()
print(f"Varianza de precio: {precio_var}")
habitaciones_med = ds3["rooms"].mean()
print(f"Media de habitaciones: {habitaciones_med}")
habitaciones_var = ds3["rooms"].var()
print(f"Varianza de habitaciones: {habitaciones_var}")
superficie_med = ds3["surface"].mean()
print(f"media de superficie: {superficie_med}")
superficie_var = ds3["surface"].var()
print(f"varianza de superficie: {superficie_var}")
baños_med = ds3["bathrooms"].mean()
print(f"Media de baños: {baños_med}")
baños_var = ds3["bathrooms"].var()
print(f"varianza de baños: {baños_var}")
# Out:
# Precio medio: 223094.48070562293
# Varianza de precio: 14921367508.04902
# Media de habitaciones: 3.0177383592017737
# Varianza de habitaciones: 0.7188858892927542
# media de superficie: 111.75222363405337
# varianza de superficie: 4263.051760316337
# Media de baños: 1.633221850613155
# varianza de baños: 0.5717968625577321

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
for population in ds3["level5"].unique():
    index_max = ds3["price"][ds3["level5"] == population].idxmax()
    dir = ds3["address"][index_max]
    price = ds3["price"][index_max]
    print(f"La casa más cara de {population} está en la dirección {dir} y cuesta {price} euros.")
# Out:
# La casa más cara de Fuenlabrada está en la dirección Calle de Paulo Freire, 5, Fuenlabrada y cuesta 490000 euros.
# La casa más cara de Alcorcón está en la dirección Alcorcón y cuesta 950000 euros.
# La casa más cara de Leganés está en la dirección Avenida Reina Sofía, Leganés y cuesta 650000 euros.
# La casa más cara de Getafe está en la dirección Getafe y cuesta 1050000 euros.

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
ds_fuen = ds3["price"][ds3["level5"] == "Fuenlabrada"]

normalized_ds_fuen = (ds_fuen-ds_fuen.mean())/(ds_fuen.std())
#print(normalized_ds_fuen)

ds_geta = ds3["price"][ds3["level5"] == "Getafe"]

normalized_ds_geta = (ds_geta-ds_geta.mean())/(ds_geta.std())
#print(normalized_ds_geta)

ds_alcor = ds3["price"][ds3["level5"] == "Alcorcón"]

normalized_ds_alcor = (ds_alcor-ds_alcor.mean())/(ds_alcor.std())
#print(normalized_ds_alcor)

ds_lega = ds3["price"][ds3["level5"] == "Leganés"]

normalized_ds_lega = (ds_lega-ds_lega.mean())/(ds_lega.std())
#print(normalized_ds_lega)

plt.hist(normalized_ds_fuen, label="Fuenlabrada", bins=15, alpha = 0.5, density=True)
plt.hist(normalized_ds_geta, label="Getafe", bins=15, alpha = 0.5, density=True)
plt.hist(normalized_ds_alcor, label="Alcorcón", bins=15, alpha = 0.5, density=True)
plt.hist(normalized_ds_lega, label="Leganés", bins=15, alpha = 0.5, density=True)
plt.title("Distribución de precios normalizados")
plt.legend()
plt.show()

# %%
norm_prices = ds3.groupby("level5")["price"].transform(lambda x: (x - x.mean()) / x.std())

for population in ds3["level5"].unique():
    plt.hist(norm_prices[ds3['level5'] == population], bins=15, alpha=0.6, label=population)

plt.title("Distribución de precios normalizados")
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
print(ds3["pps"][ds3["level5"] == "Getafe"].mean())
print(ds3["pps"][ds3["level5"] == "Getafe"].max())

print(ds3["pps"][ds3["level5"] == "Alcorcón"].mean())
print(ds3["pps"][ds3["level5"] == "Alcorcón"].max())

'''
El precio medio por metro cuadrado es mayor en Alcorcón que en Getafe, sin embargo el precio máximo por metro cuadrado corresponde a Getafe
'''
# Out:
# 2066.314949251463
# 3827.1604938271603
# 2239.302480199618
# 3698.159509202454
# '\nEl precio medio por metro cuadrado es mayor en Alcorcón que en Getafe, sin embargo el precio máximo por metro cuadrado corresponde a Getafe\n'

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
fuen = ds3["pps"][ds3["level5"] == "Fuenlabrada"]
geta = ds3["pps"][ds3["level5"] == "Getafe"]
alcor = ds3["pps"][ds3["level5"] == "Alcorcón"]
lega = ds3["pps"][ds3["level5"] == "Leganés"]

Xf = np.arange(0,fuen.size,1)
Xg = np.arange(0,geta.size,1)
Xa = np.arange(0,alcor.size,1)
Xl = np.arange(0,lega.size,1)

fig, ax = plt.subplots(2, 2, figsize=(13,8))

ax[0,0].scatter(Xf, fuen,color='red')
ax[0,0].set_title('Fuenlabrada')
ax[0,0].set_xlabel('Viviendas')
ax[0,0].set_ylabel('Precio por metro cuadrado')

ax[0,1].scatter(Xg, geta,color='blue')
ax[0,1].set_title('Getafe')
ax[0,1].set_xlabel('Viviendas')
ax[0,1].set_ylabel('Precio por metro cuadrado')

ax[1,0].scatter(Xa, alcor,color='green')
ax[1,0].set_title('Alcorcón')
ax[1,0].set_xlabel('Viviendas')
ax[1,0].set_ylabel('Precio por metro cuadrado')

ax[1,1].scatter(Xl, lega,color='yellow')
ax[1,1].set_title('Leganés')
ax[1,1].set_xlabel('Viviendas')
ax[1,1].set_ylabel('Precio por metro cuadrado')


plt.tight_layout()
plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps, Polyline, CircleMarker

# Mapa centrado en (60 grados latitud y -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (40.4168, -3.7038), zoom = 10, min_zoom = 1, max_zoom = 20, basemap=basemaps.OpenStreetMap.Mapnik)

# basemap=basemaps.Stamen.Terrain
map
# Out:
# Map(center=[40.4168, -3.7038], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
for index, file in ds3.iterrows():
     if file["level5"] == "Fuenlabrada":
          circle_marker = CircleMarker()
          circle_marker.location = [file["latitude"], file["longitude"]]
          circle_marker.radius = 2
          circle_marker.color = "blue"
          circle_marker.fill_color = "blue"
          map.add(circle_marker)
     elif file["level5"] == "Getafe":
          circle_marker = CircleMarker()
          circle_marker.location = [file["latitude"], file["longitude"]]
          circle_marker.radius = 2
          circle_marker.color = "red"
          circle_marker.fill_color = "red"
          map.add(circle_marker)
     elif file["level5"] == "Alcorcón":
          circle_marker = CircleMarker()
          circle_marker.location = [file["latitude"], file["longitude"]]
          circle_marker.radius = 2
          circle_marker.color = "green"
          circle_marker.fill_color = "green"
          map.add(circle_marker)
     elif file["level5"] == "Leganés":
          circle_marker = CircleMarker()
          circle_marker.location = [file["latitude"], file["longitude"]]
          circle_marker.radius = 2
          circle_marker.color = "yellow"
          circle_marker.fill_color = "yellow"
          map.add(circle_marker)

map
# Out:
# Map(bottom=99045.0, center=[40.4168, -3.7038], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoo…
